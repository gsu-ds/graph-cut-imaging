# %% [markdown]
# # Whats all this then?
# ---
# `A short report by Joshua Piña`
#
# For this project, I decided to work alone. I completed the algo script, my repo setup, and my presentation. Upon completion I decided to try a tool I've been wanting to test for awhile: Google Jules.
#
# I installed the cli, but decided to try the browser route first.

# %% [markdown]
# ##### There are three relatively standard ways to utilize Jules.
# 1) API
# 2) CLI
# 3) Web Browser
#
# [Google Jules Docs](https://jules.google/docs/)

# %% [markdown]
# ##### Notes:
# - I chose to use the Web Browser version first, but I did also download the CLI to test how well it would work within VSCode.
# - For my simple use cases, I wanted to document what it did and how the UI/UX was.
# - Screenshots of this can be found below, followed by Jules FAQ from Googles Documentation.

# %% [markdown]
#   `Initial request`
#   <p float="left">
#   <img src="../images/jules_tracker/jules_request.png" width="25%" />
# </p>

# %% [markdown]
# `Plan review and implementation`
# <p float="left">
#   <img src="../images/jules_tracker/review_plan.png" width="30%" />
#   <img src="../images/jules_tracker/final_stages.png" width="40%" />
# </p>

# %% [markdown]
# ##### Notes from the [Google Jules FAQ](https://jules.google/docs/faq/#what-is-jules) can be found below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
